# %% [markdown]
# <a href="https://colab.research.google.com/github/satanjj10/web-crawler-and-database_course/blob/main/%E7%88%AC%E8%9F%B22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import io
import prettytable
import json
import codecs
#搜尋多個page(頁碼)

fn = 0
for p in range(1,6,1):
    r1 = requests.get(
          "https://xapi.pcone.com.tw/search/commodities",
          headers = {
                "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36",
                "referer" : "https://www.pcone.com.tw/search?q=apple",
          },
          params = {
                "site" : "pcone",
                "direction" : "asc",
                "page": p,
                "q" : "apple",
                "sorting＂　：　"default",
                "device" : "desktop",
                "aid" : "null",
          },
          data = {}
    )
    ret = json.loads(r1.text)
    # for dd in ret["data"]["commodities"]:
    #   ret2 = requests.get(dd["images"]["small"])
    #   fn += 1
    #   with codecs.open("pcone_image/" + str(fn) + ".jpg","wb") as f:
    #     f.write(ret2.content)
      print(dd["name"],dd["price"])
# Out:
#   File "<ipython-input-12-ad1a2a7a0686>", line 21
#     "sorting＂　：　"default",
#              　 　       ^
# SyntaxError: invalid syntax

# %%
# !zip -r a.zip news_image
# Out:
#   adding: news_image/ (stored 0%)
#   adding: news_image/7.jpg (deflated 0%)
#   adding: news_image/14.jpg (deflated 0%)
#   adding: news_image/50.jpg (deflated 0%)
#   adding: news_image/97.jpg (deflated 0%)
#   adding: news_image/77.jpg (deflated 0%)
#   adding: news_image/55.jpg (deflated 0%)
#   adding: news_image/31.jpg (deflated 0%)
#   adding: news_image/39.jpg (deflated 0%)
#   adding: news_image/84.jpg (deflated 0%)
#   adding: news_image/88.jpg (deflated 0%)
#   adding: news_image/37.jpg (deflated 0%)
#   adding: news_image/56.jpg (deflated 5%)
#   adding: news_image/5.jpg (deflated 0%)
#   adding: news_image/65.jpg (deflated 0%)
#   adding: news_image/10.jpg (deflated 0%)
#   adding: news_image/8.jpg (deflated 0%)
#   adding: news_image/29.jpg (deflated 0%)
#   adding: news_image/24.jpg (deflated 0%)
#   adding: news_image/80.jpg (deflated 0%)
#   adding: news_image/42.jpg (deflated 2%)
#   adding: news_image/98.jpg (deflated 0%)
# ...

# %%
pip install beautifulsoup4

# %%
#beautiful soup 方法一
from bs4 import BeautifulSoup
import requests
import io
import prettytable
import json
import codecs

r1 = requests.get(
    "https://www.cdc.gov.tw/Bulletin/List/MmgtpeidAR5Ooai4-fgHzQ",
     headers = {
                "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
                "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
                "cookie" : "ECC=da0932b95d2e20e342fc6f865350a088400d7ee1.1652408385; _gcl_au=1.1.1448128755.1652408387; gsite=shopping; _ga_9CE1X6J1FG=GS1.1.1652408386.1.1.1652409304.34; _ga=GA1.3.1607308529.1652408387; _ga_9876543210=GS1.1.1652408386.1.1.1652409285.0; _gid=GA1.3.109828678.1652408387; FPLC=P5BTV4VNb81c92MSZRwV4rAwxOSRruTv7ZlFtZChrxt1en8yyCHi63eNaVfrHn1QylLpw7KGA1NTZSxi0iYU%2Bk9CVbnWb5vAHKkHbzeJhvUKEqV4RHedzEZQT1PpcQ%3D%3D; FPID=FPID2.3.lG%2B0WJ0lq2ZXWTYAAG365g31UJ41Afa4sxWPuKB0PNU%3D.1652408387; _fbp=fb.2.1652408387642.1930694231; venguid=b4b21fb7-533f-4444-a67c-465e38f661a6.wgc-5csj20220513; vensession=cac0df32-2ce3-47f4-9d77-654a3e6dc791.wgc-5csj20220513.se; _ga_9876543211=GS1.1.1652408792.1.1.1652409285.0; U=663fc6965513b449a4aba6c62bf77623a9b85675; ECWEBSESS=e407114e74.28227170a9ddfc93d6b6da7abf7f3188af7ebd86.1652409192; _gat_UA-115564493-1=1"
     }
)
p1 = BeautifulSoup(r1.text,"html.parser")
ret = p1.find_all("p",{
    "class" : "JQdotdotdot"
})
for dd in ret:
  print(dd.text)
# Out:
# 5月13日起開放符合口服抗病毒藥物用藥條件之COVID-19確診者，可由親友代為看診以評估使用口服抗病毒藥物
# 新增65,446例COVID-19確定病例，分別為65,385例本土及61例境外移入
# 新增57,216例COVID-19確定病例，分別為57,188例本土及28例境外移入
# 新增50,828例COVID-19確定病例，分別為50,780例本土及48例境外移入
# 「數位新冠病毒健康證明」系統版本更新，增列顯示身分證字號之需求
# 新增40,304例COVID-19確定病例，分別為40,263例本土及41例境外移入
# 今年第一批採購Pfizer-BioNTech成人劑型疫苗185.796萬劑於今日上午抵臺
# 新增44,361例COVID-19確定病例，分別為44,294例本土及67例境外移入
# 5月8日零時起，調整密切接觸者匡列以同住親友為原則，職場及學校採自主應變；取消居家隔離者電子圍籬措施
# 新增46,536例COVID-19確定病例，分別為46,377例本土及159例境外移入

# %%
#beautiful soup 方法二
from bs4 import BeautifulSoup
import requests
import io
import prettytable
import json
import codecs

for p in range(1,4,1):
    r1 = requests.get(
        "https://www.cdc.gov.tw/Bulletin/List/MmgtpeidAR5Ooai4-fgHzQ",
        headers = {
                    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
                    "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
                    "cookie" : "ECC=da0932b95d2e20e342fc6f865350a088400d7ee1.1652408385; _gcl_au=1.1.1448128755.1652408387; gsite=shopping; _ga_9CE1X6J1FG=GS1.1.1652408386.1.1.1652409304.34; _ga=GA1.3.1607308529.1652408387; _ga_9876543210=GS1.1.1652408386.1.1.1652409285.0; _gid=GA1.3.109828678.1652408387; FPLC=P5BTV4VNb81c92MSZRwV4rAwxOSRruTv7ZlFtZChrxt1en8yyCHi63eNaVfrHn1QylLpw7KGA1NTZSxi0iYU%2Bk9CVbnWb5vAHKkHbzeJhvUKEqV4RHedzEZQT1PpcQ%3D%3D; FPID=FPID2.3.lG%2B0WJ0lq2ZXWTYAAG365g31UJ41Afa4sxWPuKB0PNU%3D.1652408387; _fbp=fb.2.1652408387642.1930694231; venguid=b4b21fb7-533f-4444-a67c-465e38f661a6.wgc-5csj20220513; vensession=cac0df32-2ce3-47f4-9d77-654a3e6dc791.wgc-5csj20220513.se; _ga_9876543211=GS1.1.1652408792.1.1.1652409285.0; U=663fc6965513b449a4aba6c62bf77623a9b85675; ECWEBSESS=e407114e74.28227170a9ddfc93d6b6da7abf7f3188af7ebd86.1652409192; _gat_UA-115564493-1=1"
        },
        params = {
            "page": p
        }
    )
    p1 = BeautifulSoup(r1.text,"html.parser")
    ret = p1.find_all("div",{
        "class" : "content-boxes-v3"
    })
    for dd in ret:
      print(dd.find("a").attrs["title"])
# Out:
# 開設學齡前兒童就醫綠色通道，優先照顧兒童
# 有關網傳「防護面罩預算63.9億，快篩預算僅5264萬」之澄清說明
# 自5月14日起，新增居家隔離、自主防疫及居家檢疫3類對象快篩陽性評估管道
# 新增65,011例COVID-19確定病例，分別為64,972例本土及39例境外移入
# 5月13日起開放符合口服抗病毒藥物用藥條件之COVID-19確診者，可由親友代為看診以評估使用口服抗病毒藥物
# 新增65,446例COVID-19確定病例，分別為65,385例本土及61例境外移入
# 新增57,216例COVID-19確定病例，分別為57,188例本土及28例境外移入
# 新增50,828例COVID-19確定病例，分別為50,780例本土及48例境外移入
# 「數位新冠病毒健康證明」系統版本更新，增列顯示身分證字號之需求
# 新增40,304例COVID-19確定病例，分別為40,263例本土及41例境外移入
# 今年第一批採購Pfizer-BioNTech成人劑型疫苗185.796萬劑於今日上午抵臺
# 新增44,361例COVID-19確定病例，分別為44,294例本土及67例境外移入
# 5月8日零時起，調整密切接觸者匡列以同住親友為原則，職場及學校採自主應變；取消居家隔離者電子圍籬措施
# 新增46,536例COVID-19確定病例，分別為46,377例本土及159例境外移入
# 今(2022)年第八批採購Moderna疫苗125.09萬劑將於今(7)日下午抵臺
# 即日起增加公費PCR核酸檢驗採檢服務診所，籲請抗原快篩陽性或有症狀民眾多加利用
# 新增36,213例COVID-19確定病例，分別為36,168例本土及45例境外移入
# 指揮中心緊急增備快篩試劑，廠商須符合3資格並於投標後查驗相關文件
# 指揮中心修訂病例定義，居家隔離/檢疫對象如快篩陽性，經醫事人員確認即為確診
# 新增30,106例COVID-19確定病例，分別為30,035例本土及71例境外移入
# 指揮中心重申，政府徵用快篩試劑均依法執行，絕無圖利特定代理商
# 「Taiwan V-Watch」兒童及青少年版上線，鼓勵家長代未成年子女加入並填寫COVID-19疫苗接種後健康回報
# 今年第七批採購Moderna疫苗111.55萬劑將於今(4)日下午抵臺
# ...

# %%
#beautiful soup 方法二
from bs4 import BeautifulSoup
import requests
import io
import prettytable
import json
import codecs
fn = 0
for p in range(1,4,1):
    r1 = requests.get(
        "https://www.cdc.gov.tw/Bulletin/List/MmgtpeidAR5Ooai4-fgHzQ",
        headers = {
                    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
                    "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
                    "cookie" : "ECC=da0932b95d2e20e342fc6f865350a088400d7ee1.1652408385; _gcl_au=1.1.1448128755.1652408387; gsite=shopping; _ga_9CE1X6J1FG=GS1.1.1652408386.1.1.1652409304.34; _ga=GA1.3.1607308529.1652408387; _ga_9876543210=GS1.1.1652408386.1.1.1652409285.0; _gid=GA1.3.109828678.1652408387; FPLC=P5BTV4VNb81c92MSZRwV4rAwxOSRruTv7ZlFtZChrxt1en8yyCHi63eNaVfrHn1QylLpw7KGA1NTZSxi0iYU%2Bk9CVbnWb5vAHKkHbzeJhvUKEqV4RHedzEZQT1PpcQ%3D%3D; FPID=FPID2.3.lG%2B0WJ0lq2ZXWTYAAG365g31UJ41Afa4sxWPuKB0PNU%3D.1652408387; _fbp=fb.2.1652408387642.1930694231; venguid=b4b21fb7-533f-4444-a67c-465e38f661a6.wgc-5csj20220513; vensession=cac0df32-2ce3-47f4-9d77-654a3e6dc791.wgc-5csj20220513.se; _ga_9876543211=GS1.1.1652408792.1.1.1652409285.0; U=663fc6965513b449a4aba6c62bf77623a9b85675; ECWEBSESS=e407114e74.28227170a9ddfc93d6b6da7abf7f3188af7ebd86.1652409192; _gat_UA-115564493-1=1"
        },
        params = {
            "page": p
        }
    )
    p1 = BeautifulSoup(r1.text,"html.parser")
    ret = p1.find_all("div",{
        "class" : "content-boxes-v3"
    })
    for dd in ret:
      r2 = requests.get(
          "https://www.cdc.gov.tw/" + dd.find("a").attrs["href"],
          headers = {
                    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
                    "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
                    "cookie" : "ECC=da0932b95d2e20e342fc6f865350a088400d7ee1.1652408385; _gcl_au=1.1.1448128755.1652408387; gsite=shopping; _ga_9CE1X6J1FG=GS1.1.1652408386.1.1.1652409304.34; _ga=GA1.3.1607308529.1652408387; _ga_9876543210=GS1.1.1652408386.1.1.1652409285.0; _gid=GA1.3.109828678.1652408387; FPLC=P5BTV4VNb81c92MSZRwV4rAwxOSRruTv7ZlFtZChrxt1en8yyCHi63eNaVfrHn1QylLpw7KGA1NTZSxi0iYU%2Bk9CVbnWb5vAHKkHbzeJhvUKEqV4RHedzEZQT1PpcQ%3D%3D; FPID=FPID2.3.lG%2B0WJ0lq2ZXWTYAAG365g31UJ41Afa4sxWPuKB0PNU%3D.1652408387; _fbp=fb.2.1652408387642.1930694231; venguid=b4b21fb7-533f-4444-a67c-465e38f661a6.wgc-5csj20220513; vensession=cac0df32-2ce3-47f4-9d77-654a3e6dc791.wgc-5csj20220513.se; _ga_9876543211=GS1.1.1652408792.1.1.1652409285.0; U=663fc6965513b449a4aba6c62bf77623a9b85675; ECWEBSESS=e407114e74.28227170a9ddfc93d6b6da7abf7f3188af7ebd86.1652409192; _gat_UA-115564493-1=1"
          },
      )
      p2 = BeautifulSoup(r2.text, "html.parser")
      fn += 1
      with codecs.open("cdc/"+str(fn)+".txt","w","utf-8") as f:
        f.write(dd.find("a").attrs["title"]+"\r\n\r\n")
        for dd2 in p2.find("div",{"class" : "news-v3-in"}).find_all("div"):
          if "class" not in dd2.attrs:
            f.write(dd2.text)

# %%
# !zip -r b.zip cdc
# Out:
#   adding: cdc/ (stored 0%)
#   adding: cdc/6.txt (deflated 51%)
#   adding: cdc/21.txt (deflated 36%)
#   adding: cdc/17.txt (deflated 51%)
#   adding: cdc/13.txt (deflated 47%)
#   adding: cdc/1.txt (deflated 45%)
#   adding: cdc/18.txt (deflated 44%)
#   adding: cdc/7.txt (deflated 50%)
#   adding: cdc/26.txt (deflated 45%)
#   adding: cdc/16.txt (deflated 46%)
#   adding: cdc/11.txt (deflated 40%)
#   adding: cdc/23.txt (deflated 39%)
#   adding: cdc/22.txt (deflated 45%)
#   adding: cdc/14.txt (deflated 50%)
#   adding: cdc/24.txt (deflated 51%)
#   adding: cdc/19.txt (deflated 49%)
#   adding: cdc/20.txt (deflated 51%)
#   adding: cdc/12.txt (deflated 50%)
#   adding: cdc/30.txt (deflated 49%)
#   adding: cdc/29.txt (deflated 46%)
#   adding: cdc/4.txt (deflated 51%)
#   adding: cdc/28.txt (deflated 51%)
#   adding: cdc/9.txt (deflated 39%)
#   adding: cdc/15.txt (deflated 40%)
#   adding: cdc/3.txt (deflated 53%)
#   adding: cdc/27.txt (deflated 38%)
# ...

# %%
#beautiful soup 方法一
from bs4 import BeautifulSoup
import requests
import io
import prettytable
import json
import codecs

r1 = requests.get(
    "https://news.ebc.net.tw/realtime",
     headers = {
                "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
                "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
                "cookie" : "ECC=da0932b95d2e20e342fc6f865350a088400d7ee1.1652408385; _gcl_au=1.1.1448128755.1652408387; gsite=shopping; _ga_9CE1X6J1FG=GS1.1.1652408386.1.1.1652409304.34; _ga=GA1.3.1607308529.1652408387; _ga_9876543210=GS1.1.1652408386.1.1.1652409285.0; _gid=GA1.3.109828678.1652408387; FPLC=P5BTV4VNb81c92MSZRwV4rAwxOSRruTv7ZlFtZChrxt1en8yyCHi63eNaVfrHn1QylLpw7KGA1NTZSxi0iYU%2Bk9CVbnWb5vAHKkHbzeJhvUKEqV4RHedzEZQT1PpcQ%3D%3D; FPID=FPID2.3.lG%2B0WJ0lq2ZXWTYAAG365g31UJ41Afa4sxWPuKB0PNU%3D.1652408387; _fbp=fb.2.1652408387642.1930694231; venguid=b4b21fb7-533f-4444-a67c-465e38f661a6.wgc-5csj20220513; vensession=cac0df32-2ce3-47f4-9d77-654a3e6dc791.wgc-5csj20220513.se; _ga_9876543211=GS1.1.1652408792.1.1.1652409285.0; U=663fc6965513b449a4aba6c62bf77623a9b85675; ECWEBSESS=e407114e74.28227170a9ddfc93d6b6da7abf7f3188af7ebd86.1652409192; _gat_UA-115564493-1=1"
     }
)
p1 = BeautifulSoup(r1.text,"html.parser")
ret = p1.find_all("span",{
    "class" : "title"
})
for dd in ret:
  if dd.text != "":
    print(dd.parent.find("span",{"class" : "small-gray-text"}).text,dd.text)
# Out:
# [<span class="title">反骨正妹剪髮「臭臉痛哭」 Joeman發文道歉了</span>, <span class="title">傳曾遭性侵引退 港女星曝暗黑潛規則：令人反感</span>, <span class="title">國三連環撞波及10車！台積電工程師噴飛對向 遭輾慘死</span>, <span class="title">私吞149萬公款！台中清潔員被通緝 逃25年後「1天都免關」</span>, <span class="title">中正紀念堂車來速暫定5／17上線！每日可篩2千人</span>, <span class="title">快篩陽就給藥？台大醫點一情況 恐導致災難發生</span>, <span class="title">陪伴8年！老農淚流滿面 送別朴子最後一頭水牛</span>, <span class="title">熟睡中！惡煞持武器闖民宅！ 家人停放6部車全遭殃</span>, <span class="title">HowHow和兒隔離7天 無奈曝1事：可以看到我靈魂的空洞</span>, <span class="title">護理妹拒「偽造快篩結果」 遭揚言提告...超扯對話截圖曝光</span>, <span class="title">林志傑致勝上籃 勇士險勝領航猿寫跨季對戰10連勝</span>, <span class="title">林秀琴爆全家確診！愛女高燒40度 衝醫院淋雨排PCR</span>, <span class="title">傘友罵爆！男騎車衝飛行傘基地長下坡慘摔 獲救超糗</span>, <span class="title">控貨車駕駛肇事神隱 死亡騎士親友揪人爆衝突</span>, <span class="title">獨／氣「洗好車放路邊淋雨」給1星負評 業者衝警局提告</span>, <span class="title">獨／大甲石頭屋再遭清運 屋主怒：政府搶百姓財產？</span>, <span class="title">嘉義9旬老婦人送醫不治 經PCR採檢確診</span>, <span class="title">獨／護理師控：全家白天要上班 快篩實名制「仍難買」</span>, <span class="title">民眾排隊領免費快篩遭諷乞丐
# ...

# %%
from bs4 import BeautifulSoup
import requests
import io
import prettytable
import json
import codecs

r1 = requests.get(
    "http://teaching.bo-yuan.net/",
     headers = {
                "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
                "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
                "cookie" : "PHPSESSID=iaufh4do8l1v418ju68to51cjd"
     }
)
with codecs.open("1.html","w","utf-8") as f:
  f.write(r1.text)

# %%
#利用程式自動登入
from bs4 import BeautifulSoup
import requests
import io
import prettytable
import json
import codecs

r1 = requests.get(
    "http://teaching.bo-yuan.net/",
     headers = {
                "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
                "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
                "cookie" : "PHPSESSID=iaufh4do8l1v418ju68to51cjd"
     },
     params = {"ex" : "login"},
     data = {
         "ex[class]" : "626eaa0ec3e72",
         "ex[username]" : "00示範",
         "ex[password]" : "test"
     }
)
with codecs.open("1.html","w","utf-8") as f:
  f.write(r1.text)

# %%
#作業2
import requests
import prettytable
import json

in_text = input("關鍵字:")
r1 = requests.get(
    "https://ecshweb.pchome.com.tw/search/v3.3/all/results",
    headers = {
          "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
          "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
          "cookie" : "ECC=da0932b95d2e20e342fc6f865350a088400d7ee1.1652408385; _gcl_au=1.1.1448128755.1652408387; gsite=shopping; _ga_9CE1X6J1FG=GS1.1.1652408386.1.1.1652409304.34; _ga=GA1.3.1607308529.1652408387; _ga_9876543210=GS1.1.1652408386.1.1.1652409285.0; _gid=GA1.3.109828678.1652408387; FPLC=P5BTV4VNb81c92MSZRwV4rAwxOSRruTv7ZlFtZChrxt1en8yyCHi63eNaVfrHn1QylLpw7KGA1NTZSxi0iYU%2Bk9CVbnWb5vAHKkHbzeJhvUKEqV4RHedzEZQT1PpcQ%3D%3D; FPID=FPID2.3.lG%2B0WJ0lq2ZXWTYAAG365g31UJ41Afa4sxWPuKB0PNU%3D.1652408387; _fbp=fb.2.1652408387642.1930694231; venguid=b4b21fb7-533f-4444-a67c-465e38f661a6.wgc-5csj20220513; vensession=cac0df32-2ce3-47f4-9d77-654a3e6dc791.wgc-5csj20220513.se; _ga_9876543211=GS1.1.1652408792.1.1.1652409285.0; U=663fc6965513b449a4aba6c62bf77623a9b85675; ECWEBSESS=e407114e74.28227170a9ddfc93d6b6da7abf7f3188af7ebd86.1652409192; _gat_UA-115564493-1=1"
    },
    params = {
          "q" : in_text,
          "page" : 1,
          "sort" : "sale/dc"
    },
    data = {}
)
ret = json.loads(r1.text)
p1 = prettytable.PrettyTable(["名稱","價格"])
p1.align["名稱"] = "l"
for dd in ret["prods"]:
  p1.add_row([dd["name"],dd["price"]])
print(p1)    

while True:
  in_page = int(input("前往頁碼:"))
  if in_page >=101:
    print("頁碼超過範圍！")
    break
  else:
    r2 = requests.get(
        "https://ecshweb.pchome.com.tw/search/v3.3/all/results",
        headers = {
              "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
              "referer" : "https://ecshweb.pchome.com.tw/search/v3.3/?q=acer&scope=all",
              "cookie" : "ECC=da0932b95d2e20e342fc6f865350a088400d7ee1.1652408385; _gcl_au=1.1.1448128755.1652408387; gsite=shopping; _ga_9CE1X6J1FG=GS1.1.1652408386.1.1.1652409304.34; _ga=GA1.3.1607308529.1652408387; _ga_9876543210=GS1.1.1652408386.1.1.1652409285.0; _gid=GA1.3.109828678.1652408387; FPLC=P5BTV4VNb81c92MSZRwV4rAwxOSRruTv7ZlFtZChrxt1en8yyCHi63eNaVfrHn1QylLpw7KGA1NTZSxi0iYU%2Bk9CVbnWb5vAHKkHbzeJhvUKEqV4RHedzEZQT1PpcQ%3D%3D; FPID=FPID2.3.lG%2B0WJ0lq2ZXWTYAAG365g31UJ41Afa4sxWPuKB0PNU%3D.1652408387; _fbp=fb.2.1652408387642.1930694231; venguid=b4b21fb7-533f-4444-a67c-465e38f661a6.wgc-5csj20220513; vensession=cac0df32-2ce3-47f4-9d77-654a3e6dc791.wgc-5csj20220513.se; _ga_9876543211=GS1.1.1652408792.1.1.1652409285.0; U=663fc6965513b449a4aba6c62bf77623a9b85675; ECWEBSESS=e407114e74.28227170a9ddfc93d6b6da7abf7f3188af7ebd86.1652409192; _gat_UA-115564493-1=1"
        },
        params = {
              "q" : in_text,
              "page" : in_page,
              "sort" : "sale/dc"
        },
        data = {}
    )
    ret2 = json.loads(r2.text)
    for dd in ret2["prods"]:   
      p1.add_row([dd["name"],dd["price"]])
    print(p1)
# Out:
# 關鍵字:apple
# +--------------------------------------------------------------------------------------------------+-------+
# | 名稱                                                                                             |  價格 |
# +--------------------------------------------------------------------------------------------------+-------+
# | Apple iPhone SE (128G)-星光色(MMXK3TA/A)                                                         | 15288 |
# | LC05 Lightning充電傳輸集線器 白色                                                                |  499  |
# | 《PINYI》MFi 認證 充電線 適用 iPhone 蘋果 Apple 傳輸線 lightning USB-A 數據線-1M                 |  550  |
# | AirPods 3 保護套 無線藍牙耳機 保護殼 第3代 舒適矽膠 掛勾設計 適用 Apple 蘋果 -簡約白             |  390  |
# | AirPods 3 保護套 無線藍牙耳機 保護殼 第3代 舒適矽膠 掛勾設計 適用 Apple 蘋果 -淺砂粉             |  390  |
# | APPLE IPhone13 / IPhone13Pro 高規鋼化膜保護貼鋼化玻璃保護膜2.5D滿版絲印手機玻璃保護貼            |  199  |
# | 【o-one】Apple iPhone13(6.1吋) 軍功防摔手機殼 保護殼 手機套 保護套 軟殼 防撞 耐摔                |  490  |
# ...

# %%
#作業3
from bs4 import BeautifulSoup
import requests
import prettytable

r1 = requests.get(
    "https://www.cwb.gov.tw/V8/C/W/TemperatureTop/County_TMax_T.html",
     headers = {
            "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0",
            "cookie" : "TS010c55bd=0107dddfefae77605d3793f47ab618502edab991a0041dba252680da8724d27253e771a6506bd996d3ded316fa41d538e0f96e9e1d; TS558d33eb027=08dc4bbcbbab20007d52365be573a39994b2b5d3206bb06d6043b1926a26138791437e47ff8d68ab08c8ac7327113000b237fa2704f45d730b2e2f02f24bd82c3781728019d6de2a8e8a7dd542ae5a57b8c6baaa29c22492349d5fe36f9271bd; _ga_K6HENP0XVS=GS1.1.1652432241.2.1.1652433772.0; _ga=GA1.3.14886383.1652428592; _gid=GA1.3.1235924347.1652428592"
     },
     params = {
           "ID" : "Fri%20May%2013%202022%2017:22:52%20GMT+0800%20(%E5%8F%B0%E5%8C%97%E6%A8%99%E6%BA%96%E6%99%82%E9%96%93"
     }
)
p1 = BeautifulSoup(r1.text,"html.parser")
ret = p1.find_all("th",{"scope" : "row"})
f = prettytable.PrettyTable(["地區","氣溫"], encoding = "utf-8")
for dd in ret:
  a = dd.text,dd.parent.find("span",{"class" : "tem-C is-active"}).text
  f.add_row([a[0],a[1]])
print(f)
# Out:
# +--------+------+
# |  地區  | 氣溫 |
# +--------+------+
# | 基隆市 | 20.9 |
# | 臺北市 | 21.2 |
# | 新北市 | 22.3 |
# | 桃園市 | 20.8 |
# | 新竹市 | 20.3 |
# | 新竹縣 | 20.5 |
# | 苗栗縣 | 21.1 |
# | 臺中市 | 22.9 |
# | 彰化縣 | 22.9 |
# | 南投縣 | 23.3 |
# | 雲林縣 | 22.9 |
# | 嘉義市 | 24.1 |
# | 嘉義縣 | 24.2 |
# | 臺南市 | 25.0 |
# | 高雄市 | 26.6 |
# | 屏東縣 | 26.6 |
# | 宜蘭縣 | 23.4 |
# | 花蓮縣 | 23.7 |
# | 臺東縣 | 27.9 |
# | 澎湖縣 | 23.3 |
# | 金門縣 | 18.2 |
# | 連江縣 | 16.1 |
# +--------+------+
